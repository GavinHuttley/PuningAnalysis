# %%
from cogent3 import open_data_store, get_app
from cogent3.app import io as io_app

# %%
loader_db = io_app.load_db()
input_path = '/Users/gulugulu/clock/mammal_orthologs_hsap_1/triples_representative_subset.sqlitedb'
input_data_store = open_data_store(input_path)

# %%
loader_db(input_data_store[1])
# Out:
# 3 x 1261 dna alignment: Greater_bamboo_lemur[GTTCAGAGAG...], Ma's_night_monkey[GTTCAGAGAG...], Prairie_vole[GTTCAGAGAG...]

# %%
loader_db.app_type
# Out:
# <AppType.LOADER: 'loader'>

# %%
from clock_project.genome_analysis.bootstrapping.clock_violation_bootstrapping import test_hypothesis_clock_model

# %%
toc_bootstrapper = test_hypothesis_clock_model(num_reps = 2)
out_dstore = open_data_store('~/Desktop/test', mode="w", suffix="json")

# %%
clock_app = loader_db + toc_bootstrapper + write_json_app

# %%
def configure_parallel(parallel: bool, mpi: int, num_processes: int) -> dict:
    mpi = None if mpi < 2 else mpi
    parallel = True if mpi else parallel
    par_kw = (
        dict(max_workers=mpi, use_mpi=True)
        if mpi
        else dict(max_workers=num_processes, use_mpi=False)
    )
    return {"parallel": parallel, "par_kw": par_kw}

parallel_config = configure_parallel(
    parallel=True, mpi=3, num_processes=3
)

# %%
clock_app.apply_to(input_data_store[0:3], show_progress=True,
        cleanup=True,
        **parallel_config,)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 clock_app.apply_to(input_data_store[0:3], show_progress=True,
#       2         cleanup=True,
#       3         **parallel_config,)
#
# File ~/opt/anaconda3/envs/clock/lib/python3.13/site-packages/cogent3/app/composable.py:850, in _apply_to(self, dstore, id_from_source, parallel, par_kw, logger, cleanup, show_progress)
#     847     logger.log_versions(["cogent3"])
#     849 inputs = _proxy_input(inputs.values())
# --> 850 for result in self.as_completed(
#     851     inputs,
#     852     parallel=parallel,
#     853     par_kw=par_kw,
#     854     show_progress=show_progress,
#     855 ):
#     856     member = self.main(
#     857         data=getattr(result, "obj", result),
#     858         identifier=id_from_source(result.source),
#     859     )
#     860     if self.logger:
#
# ...

# %%
out_dir = '~/clock/triples_representative_subset_json'
for file in input_data_store.completed:
    aln = loader_db(file)
    identifier = file.unique_id
    output_datastore = open_data_store(out_dir, mode="w", suffix="json")
    write_json_app = get_app("write_json", data_store=output_datastore)
    write_json_app(aln, identifier=identifier)

# %%
input_data_store[1].unique_id
# Out:
# DataMember(data_store=/Users/gulugulu/clock/mammal_orthologs_hsap_1/triples_representative_subset.sqlitedb, unique_id=ENSG00000137962_128.fa)

# %%
json_folder = '~/clock/triples_representative_subset_json'
input_data_store_json = open_data_store(json_folder, mode="r", suffix="json")
loader_json = get_app("load_json")
aln = loader_json(input_data_store_json[1])

# %%
aln.info
# Out:
# {'Refs': {},
#  'source': '/Users/gulugulu/clock/mammal_orthologs_hsap_1/taxanomic_triples_alignments/ENSG00000116711/200.fa',
#  'triples_species_name': {'ingroup1': 'Prairie_vole',
#   'ingroup2': 'Olive_baboon',
#   'outgroup': 'Pig'}}

# %%
a = None
mpi = True if a else None

# %%
mpi

# %%
import numpy as np
from cogent3 import get_app, open_data_store
import plotly.express as px

from clock_project.genome_analysis.sequence_alignment_filtering import (common_name_renamer,
                                                            cpos3, aligner, filter)
import json
import os
import numpy as np
import glob
from cogent3 import get_app, open_data_store
from cogent3.app.data_store import DataMember

# %%
seq_dir = "/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies"
output_dir = '/Users/gulugulu/Desktop/honours/data_local/mammal_genome_codon_aln'

# %%
input_dstore_seqs = open_data_store(seq_dir, suffix="fa", mode="r")
loader = get_app("load_unaligned", format="fasta", moltype="dna")

# %%
valid_homology_list = []
prob_homology_list = []
species_less_than_3 = []
small_sample_size = []
short_alignment = []
valid_homology_index_dict = {}
alignment_lengths = {}
sample_size_dict = {}

# %%
for i in range(len(input_dstore_seqs.completed)):
    path = input_dstore_seqs.completed[i]
    file_name = path.unique_id.split('.')[0]
    seqs = loader(path)
    seqs_filtered = filter(seqs)
    try:
        if seqs_filtered.num_seqs < 3:
            species_less_than_3.append(path)
        else: 
            aln = aligner(seqs_filtered)
            aln_3rd = cpos3(aln)
            aln_3rd_no_degenerates = aln_3rd.no_degenerates()
            alignment_length = aln_3rd_no_degenerates.get_lengths()[0]
            sample_size = aln_3rd_no_degenerates.num_seqs
            alignment_lengths[file_name] = alignment_length
            sample_size_dict[file_name] = sample_size
            if aln_3rd_no_degenerates.num_seqs < 30:
                small_sample_size.append(path)
                print(f"Path added to small size: {path} with length {alignment_length}, sample size {sample_size}")
            
            elif alignment_length < 350:
                short_alignment.append(path)
                print(f"Path added to short alignment: {path} with length {alignment_length}, sample size {sample_size}")
            
            else:
                valid_homology_list.append(path)
                valid_homology_index_dict[file_name] = i
                print(f"Path added to valid_homology_list: {path} with length {alignment_length}, sample size {sample_size}")
    
    except Exception as e:
        print(e)
        prob_homology_list.append(path)
# Out:
# Path added to valid_homology_list: ENSG00000157184.fa with length 363, sample size 64
# Path added to short alignment: ENSG00000131791.fa with length 72, sample size 61
# Path added to short alignment: ENSG00000174791.fa with length 290, sample size 59
# 'NoneType' object has no attribute 'get_lengths'
# Path added to short alignment: ENSG00000143595.fa with length 40, sample size 48
# Path added to short alignment: ENSG00000134365.fa with length 17, sample size 35
# Path added to short alignment: ENSG00000127054.fa with length 8, sample size 60
# Path added to small size: ENSG00000120937.fa with length 171, sample size 3
# Path added to valid_homology_list: ENSG00000067704.fa with length 403, sample size 59
# Path added to short alignment: ENSG00000143847.fa with length 134, sample size 61
# Path added to short alignment: ENSG00000066468.fa with length 15, sample size 61
# Path added to short alignment: ENSG00000187862.fa with length 78, sample size 50
# ...

# %%
# valid_homology_list = ['DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000157184.fa)',
#  'DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000067704.fa)',
#  'DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000165995.fa)',
#  'DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000119912.fa)',
#  'DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000177888.fa)',
#  'DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116679.fa)',
#  'DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143630.fa)',
#  'DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000117834.fa)',
#  'DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198952.fa)',
#  'DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000174804.fa)',
#  'DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000117139.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137975.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000135870.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000148498.fa)',
# 'DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143228.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000177354.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137642.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137941.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000158966.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000197136.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000263528.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000135763.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000177103.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000000457.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000248746.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000023171.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000166004.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000174606.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000187714.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000178462.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000134250.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116729.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000117593.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000117713.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000159164.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000081248.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198797.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000138193.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000127124.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000138131.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000023839.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000085552.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000174684.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000010292.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000150593.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143473.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000117707.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137497.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000166317.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000133059.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000172893.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000176148.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000185278.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000197147.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000158816.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137672.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000255561.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000197106.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000030066.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000171988.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000205339.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137474.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000122218.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000168066.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000156510.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000065526.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116748.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000165731.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000196914.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000165494.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000163349.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143624.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000094975.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000060237.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000138161.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000107938.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000069702.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000110344.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000066135.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000184144.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000118193.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000011405.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000133019.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000163867.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143318.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000058453.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000162688.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000111667.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116147.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000265203.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000173599.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198730.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000117425.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000133805.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000110002.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000134255.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000142798.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000182134.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000138182.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143476.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116678.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000165813.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000138316.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000129173.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000138347.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143442.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000119927.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000163873.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116254.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000151240.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000047621.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116194.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000151062.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000197142.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000173898.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000171608.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000086015.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000171488.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143278.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000262655.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000048649.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198198.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000037637.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000134709.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000156515.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143379.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000126705.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137727.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198700.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000239306.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000149289.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000052841.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000264522.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000085433.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198837.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198734.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000157077.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000142949.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000054118.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000176986.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000162105.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000089597.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000187151.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000162775.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000169231.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000162601.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000110514.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000127481.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000160584.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000189195.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000254986.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000172375.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000123836.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000130766.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000149292.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116830.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000158055.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000066557.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000154143.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000060339.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000095713.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000166507.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000170382.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000107581.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000151461.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000186635.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000197893.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000236287.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000108231.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000119285.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000166189.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000173662.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000254470.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198216.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143061.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000051009.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000134780.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000110497.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000142661.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000139197.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116544.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000204624.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000197444.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000135365.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000132694.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000165449.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143479.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000075945.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000149311.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000095587.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198799.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000181333.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000095564.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000014914.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000152778.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000107863.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000107731.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000162670.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000162621.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000059573.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143105.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000170759.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000048707.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000132128.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000136643.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000215009.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000162630.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000064309.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000055732.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143093.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000110756.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000107771.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000197901.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000156113.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143569.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000007933.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000107957.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000095464.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000018625.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000129159.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000257315.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000149091.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000170325.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000107862.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000152779.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000188487.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000162402.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000176102.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000027644.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116128.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000006071.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000076321.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000066279.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000156599.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000062650.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000065243.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000146463.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000065183.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000133056.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000166349.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000162711.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000111679.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000243710.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000163125.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000121957.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000132716.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000095627.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000118873.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000172350.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000086827.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000139182.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000121621.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000107611.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000130695.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143322.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000171492.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000127463.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000110713.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000180720.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000015171.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000133216.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000162607.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000170959.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000167325.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116199.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000173456.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000058668.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000151503.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000260314.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000170242.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000085999.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000170145.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000151655.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000133789.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000196878.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000109906.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000156097.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198739.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116711.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116903.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000077943.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000058085.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000158292.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000177853.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000155229.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000149428.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000110427.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000082805.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000171862.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137699.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000160695.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000187122.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143107.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000134644.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000185085.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000117000.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143374.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000132259.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000173621.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000073614.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000134697.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000108175.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000135829.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143127.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000148942.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000080854.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000091664.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000157881.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143393.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000125945.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000152578.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000110318.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000154134.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000107593.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000117859.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000121931.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116731.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000121486.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116793.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000111262.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116991.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000186603.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000233436.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000138119.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000170322.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000078618.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000148634.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000162613.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000087053.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000118058.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137478.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198162.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000283703.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000162736.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000148843.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000152092.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000148600.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000160691.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000008323.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143344.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000182934.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143126.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000148700.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000152104.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000166169.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000148516.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116584.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000149256.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000156395.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000149262.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000118733.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000163354.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000142627.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000109927.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000154222.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000075826.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000169418.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000135372.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116745.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116906.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000169174.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000117114.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000110422.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000150347.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000134744.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000136750.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000160703.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000117322.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000108055.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000108061.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000148584.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000076356.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000016490.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000011021.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000149295.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000151553.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116984.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000085998.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116852.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000042781.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000084652.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000107815.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000081026.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000196968.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000107854.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000126107.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000064703.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000142945.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000090020.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000142623.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000121753.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000196323.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143341.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143324.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000087365.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000133816.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000081019.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000155380.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000197429.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000197959.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143776.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000213171.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000009307.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000075151.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000266028.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000054523.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000135775.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116183.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198018.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000088035.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000099250.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000135837.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143079.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000070985.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000175216.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000203965.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137745.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000180488.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000134262.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000117477.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000165970.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143643.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116539.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000120451.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000089876.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000122482.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000155363.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000134256.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143515.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000165434.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000184588.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000107719.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000214655.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116688.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000149269.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000174576.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000110237.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000138315.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000177000.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000148948.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137674.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000172977.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137700.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000158636.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000149972.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000066056.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137710.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000007341.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000135862.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000076258.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000072952.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000047410.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000182022.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000134343.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000116698.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198492.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000065613.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000110171.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000095539.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143434.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000117600.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198626.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000110060.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000163399.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198825.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000085840.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198561.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000020129.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000092853.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137675.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000166106.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000149403.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000036549.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000166341.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000178028.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000035403.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000149782.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000000460.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137507.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000149476.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000158850.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000168539.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000187486.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000129083.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000117724.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000122870.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000174502.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000010165.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000169641.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000167986.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000110075.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000173327.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000198691.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000174516.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000110799.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000177054.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000225830.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000118200.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000069248.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000060718.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000137962.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000204033.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000175097.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000090686.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000183801.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000075391.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000057468.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143702.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143493.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000169826.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000165732.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000129151.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000149308.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000154309.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000187554.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000122483.fa)',
# ' DataMember(data_store=/Users/gulugulu/Desktop/honours/data_local_2/sampled_homologies_3000, unique_id=ENSG00000143514.fa)']

# %%
len(valid_homology_list), len(small_sample_size), len(short_alignment), len(prob_homology_list), len(species_less_than_3)
# Out:
# (353, 376, 2570, 548, 116)

# %%
i = 0
for gene, length in alignment_lengths.items():
    if length > 550:
        i += 1
print(i)
# Out:
# 136

# %%
seq_output_dir = '/Users/gulugulu/Desktop/honours/data_local_2/sequences_filterd_650_threshold'
aln_full_output_dir = '/Users/gulugulu/Desktop/honours/data_local_2/alignments_full_filtered_650_threshold'
aln_3rd_output_dir = '/Users/gulugulu/Desktop/honours/data_local_2/alignments_3rd_filtered_650_threshold'

# %%
out_dstore1 = open_data_store(seq_output_dir, mode="w", suffix="json")
out_dstore2 = open_data_store(aln_full_output_dir, mode="w", suffix="json")
out_dstore3 = open_data_store(aln_3rd_output_dir, mode="w", suffix="json")

# %%
write_json_app1 = get_app("write_json", data_store=out_dstore1)
write_json_app2 = get_app("write_json", data_store=out_dstore2)
write_json_app3 = get_app("write_json", data_store=out_dstore3)

# %%
sub_alignment_lengths = {}
seqs_dict = {}
aln_dict = {}
aln_3rd_no_degenerates_dict = {}
for index in valid_homology_index_dict.values():    
    path = input_dstore_seqs.completed[index]
    unique_id = path.unique_id.split('.')[0]
    print(unique_id)
    try:
        seqs = loader(path)
        seqs_filtered = filter(seqs)
        aln = aligner(seqs_filtered)
        aln_3rd = cpos3(aln)
        aln_3rd_no_degenerates = aln_3rd.no_degenerates()
        alignment_length = aln_3rd_no_degenerates.get_lengths()[0]
        print(alignment_length)
        if alignment_length > 550:
            sub_alignment_lengths[unique_id] = alignment_length
            seqs_dict[unique_id] = seqs_filtered
            aln_dict[unique_id] = aln
            aln_3rd_no_degenerates_dict[unique_id] = aln_3rd_no_degenerates
        # if alignment_length > 500:
        #     renamed_filtered_seq = common_name_renamer(seqs_filtered)
        #     renamed_full_aln = common_name_renamer(aln)
        #     renamed_aln_3rd_no_degenerates = common_name_renamer(aln_3rd_no_degenerates)
        #     write_json_app1(renamed_filtered_seq, identifier=f'{unique_id}.json')
        #     write_json_app2(renamed_full_aln, identifier=f'{unique_id}.json')
        #     write_json_app3(renamed_aln_3rd_no_degenerates, identifier=f'{unique_id}.json')
    except Exception as e:
        print(e)
# Out:
# ENSG00000157184
# 363
# ENSG00000067704
# 403
# ENSG00000165995
# 380
# ENSG00000119912
# 473
# ENSG00000177888
# 629
# ENSG00000116679
# 531
# ENSG00000143630
# 537
# ENSG00000198952
# 742
# ENSG00000117139
# 566
# ENSG00000137975
# 501
# ENSG00000135870
# 491
# ENSG00000177354
# 430
# ENSG00000137642
# 359
# ENSG00000137941
# 405
# ENSG00000158966
# 919
# ENSG00000135763
# 416
# ENSG00000248746
# 539
# ENSG00000023171
# 367
# ENSG00000178462
# 360
# ENSG00000134250
# 767
# ENSG00000138111
# 381
# ENSG00000117713
# 427
# ENSG00000120457
# 361
# ENSG00000081248
# 620
# ENSG00000143614
# 367
# ENSG00000138193
# 1077
# ENSG00000127124
# 1322
# ENSG00000138131
# 510
# ENSG00000138160
# 356
# ENSG00000023839
# 781
# ENSG00000150593
# 440
# ENSG00000117707
# 628
# ENSG00000137497
# 460
# ENSG00000133059
# 670
# ENSG00000185278
# 420
# ENSG00000197147
# 582
# ENSG00000111642
# 763
# ENSG00000158816
# 480
# ENSG00000255561
# 527
# ENSG00000197106
# 687
# ENSG00000030066
# 572
# ...

# %%
np.mean(list(sub_alignment_lengths.values()))
# Out:
# 798.9153846153846

# %%
keys = list(sub_alignment_lengths.keys())

# %%
for key in keys:
    seqs_filtered = seqs_dict[key]
    aln = aln_dict[key]
    aln_3rd_no_degenerates = aln_3rd_no_degenerates_dict[key]
    renamed_filtered_seq = common_name_renamer(seqs_filtered)
    renamed_full_aln = common_name_renamer(aln)
    print(renamed_full_aln.get_lengths()[0])
    renamed_aln_3rd_no_degenerates = common_name_renamer(aln_3rd_no_degenerates)
    print(renamed_aln_3rd_no_degenerates.get_lengths()[0])
    write_json_app1(renamed_filtered_seq, identifier=f'{key}.json')
    write_json_app2(renamed_full_aln, identifier=f'{key}.json')
    write_json_app3(renamed_aln_3rd_no_degenerates, identifier=f'{key}.json')
# Out:
# 2727
# 629
# 3048
# 742
# 4632
# 566
# 3858
# 919
# 7413
# 767
# 5559
# 620
# 6885
# 1077
# 7218
# 1322
# 4644
# 781
# 2211
# 628
# 2793
# 670
# 2409
# 582
# 5745
# 763
# 2181
# 687
# 4206
# 572
# 6645
# 778
# 3699
# 689
# 11019
# 1077
# 4452
# 656
# 5058
# 1198
# 3201
# 733
# 4947
# 797
# 4596
# 658
# 4074
# 706
# 3732
# 1103
# 3471
# 867
# 3621
# 911
# 5313
# 635
# 2598
# 625
# 4227
# 835
# 7161
# 808
# 2409
# 661
# 4797
# 731
# 3423
# 660
# 3339
# 1072
# 2970
# 830
# 2649
# 746
# 3813
# 695
# 2079
# 620
# 2469
# 566
# 6809
# 689
# 2916
# 586
# 3897
# 618
# 4311
# 743
# 3714
# 618
# 2990
# 557
# 5547
# 831
# 5604
# 608
# 13164
# 2754
# 3714
# 826
# 3333
# 775
# 2572
# 562
# 2940
# 942
# 5577
# 1191
# 7809
# 1075
# 4278
# 612
# 5019
# 702
# 3126
# 827
# 3108
# 561
# 10884
# 728
# 3546
# 570
# 3621
# 676
# 4362
# 643
# 4125
# 882
# 2211
# 628
# 3516
# 772
# 3711
# 727
# 4386
# 722
# 2823
# 668
# 4602
# 617
# 3195
# 955
# 5742
# 1391
# 3825
# 727
# 5166
# 1287
# 6240
# 836
# 11892
# ...

# %%
for gene, aln in aln_dict.items():
    print(aln.alignment_quality())
# Out:
# 4599.858191920717
# 4588.109617378837
# 5405.128586139803
# 4987.645232842647
# 5704.7153952815725
# 7175.970625708386
# 8779.845045598404
# 10856.882411991086
# 6742.748004188383
# 4015.153784804806
# 4221.486231103066
# 3583.4023110256267
# 9106.36766938805
# 3869.893426505909
# 5489.815291232863
# 7918.7362758346835
# 5984.353156178602
# 10051.96645782608
# 6349.75434739159
# 6572.024377578086
# 5208.566225767983
# 5459.962038552671
# 7373.446153312304
# 6229.381523237537
# 5407.352844425991
# 5586.836050665416
# 5921.182413047512
# 4501.545871583642
# 3756.147035192218
# 6052.266155788831
# 7969.876501837816
# 3977.495153600078
# 4218.722250943874
# 5941.017278682153
# 6060.522260408055
# 4962.846639132614
# 4597.454601963562
# 6482.494795441717
# 3740.2674238512936
# 3738.419356887888
# 7957.412471636086
# 4601.228699279145
# 5989.284096370416
# 6184.591365721755
# 5521.704528831719
# 4677.296597569841
# 7718.8235434008675
# 6856.8485625925805
# 21097.507856061526
# ...

# %%
aln_dict['ENSG00000116128']
# Out:
# 61 x 4569 dna alignment: papio_anubis-ENSPANG00000021034[----------...], chlorocebus_sabaeus-ENSCSAG00000018384[----------...], rhinopithecus_bieti-ENSRBIG00000018886[----------...], ...

# %%
for gene, aln in aln_3rd_no_degenerates_dict.items():
    print(aln.alignment_quality())
# Out:
# 939.2098374459258
# 1042.3630070136846
# 592.5094233717859
# 1156.3766318462474
# 583.4653553183175
# 812.7030207561618
# 1240.2175981430337
# 1886.630433899555
# 1045.6786106022473
# 1027.5701128699718
# 962.9784569590367
# 748.0777726998972
# 1133.7850841377904
# 1059.3929806486426
# 671.1739073211627
# 1039.0511660064608
# 993.6962014043327
# 1283.076449567679
# 919.4946813274712
# 1502.015210683551
# 1005.8112169876807
# 914.5926658457029
# 913.8408440157004
# 969.0906493276354
# 1303.861058937821
# 1269.5476797961599
# 1313.4090047268623
# 642.3568641175596
# 870.3912387890932
# 1073.9881510045225
# 934.7377741760531
# 885.2791360620415
# 618.997216310544
# 1033.8440597245167
# 1779.6690791162926
# 1267.5480588012588
# 1166.2645146886803
# 1098.1081523853513
# 1022.8169109045657
# 745.1429052789375
# 813.7932254765653
# 885.7918766128137
# 947.2033152971512
# 979.2093644601571
# 802.8926953525521
# 789.8828196307194
# 1265.332686120545
# 715.6315438247874
# 3779.9951226919743
# ...

# %%
# def get_pairwise_jsd_genetic_distance(path):
#     seqs = loader(path)
#     seqs_filtered = filter(seqs)
#     seqs_filtered_no_stop_codon = seqs_filtered.trim_stop_codons(strict=True)
#     aligned = codon_aligner(seqs_filtered_no_stop_codon)
#     just3rd_aligned = cpos3(aligned)
#     just3rd_aligned_no_degenerates = just3rd_aligned.no_degenerates(motif_length=3)
#     alignment_length = just3rd_aligned_no_degenerates.seq_len
#     taxa_num = just3rd_aligned_no_degenerates.num_seqs
#     pairwise_distance = just3rd_aligned_no_degenerates.distance_matrix(calc='tn93', show_progress=False, drop_invalid=True)
#     pairwise_distance_array = pairwise_distance.array
#     nuc_freqs = just3rd_aligned_no_degenerates.probs_per_seq()
#     sub_nuc_freqs = {}
#     for key in pairwise_distance.keys():
#         sub_nuc_freqs[key] = nuc_freqs[key]

#     pairwise_jsd = pairwise_jsd_matrix(sub_nuc_freqs)
#     pairwise_distance_values = pairwise_distance_array[np.triu_indices(n=pairwise_distance_array.shape[0], k=1)]
#     pairwise_jsd_values = pairwise_jsd[np.triu_indices(n=pairwise_jsd.shape[0], k=1)]
#     num_compare = pairwise_jsd.shape[0]
#     num_compare2 = len(pairwise_jsd_values)

#     return pairwise_distance_values, pairwise_jsd_values, alignment_length, taxa_num, num_compare, num_compare2

# %%
# import os
# from scipy.stats import pearsonr

# species_data = {}
# correlation_info = {}
# for path in valid_homology_list_4000:
#     filename = os.path.basename(path)
#     gene_name = os.path.splitext(filename)[0]
#     pairwise_distance, pairwise_jsd, alignment_length, taxa_num, num_compare, num_compare2 = get_pairwise_jsd_genetic_distance(path)
#     col, p_value = pearsonr(pairwise_jsd, pairwise_distance)
#     correlation_info[gene_name] = {'correlation_factor': col, 'p_value': p_value}
#     species_data[gene_name]  = {'pairwise_distance': pairwise_distance, 'pairwise_jsd': pairwise_jsd, 'col': col, 'p_value': p_value, 'alignment_length': alignment_length, 'taxa number': taxa_num, 'number of taxa2': num_compare, 'number of comparison': num_compare2}


# for key, value in species_data.items():
#     for subkey, subvalue in value.items():
#         if isinstance(subvalue, np.ndarray):
#             species_data[key][subkey] = subvalue.tolist()

# with open ('/Users/gulugulu/repos/PuningAnalysis/results/output_data/species_data2.json', 'w') as outfile2:
#     json.dump(species_data, outfile2)

# %%
# path = '/Users/gulugulu/Desktop/honours/data_local/whole_genome_mammal87/sampled_homologies/ENSG00000116221.fa'
# pairwise_distance, pairwise_jsd, alignment_length, taxa_num, num_compare, num_compare2 = get_pairwise_jsd_genetic_distance(path)
# import plotly.graph_objects as go

# # Create the scatter plot
# fig = go.Figure(data=go.Scatter(x=np.log10(pairwise_jsd), y=pairwise_distance, mode='markers'))

# # Update plot layout
# fig.update_layout(
#     title='Gene: MRPL37',
#     xaxis_title='Log10(Jensen-Shannon Divergence)',
#     yaxis_title='Pairwise Distance (tn93)',
#     template="plotly_white"  
# )

# # Show the plot
# fig.show()
# fig.write_image('jsd_genetic_distance_scatters_MRPL37.pdf')

# %% [markdown]
# Range of JSD

# %%
# with open ('/Users/gulugulu/repos/PuningAnalysis/results/output_data/species_data.json', 'r') as infile:
#     species_data = json.load(infile)

# %%
# JSD_value_range = []
# for name in species_data.keys():
#     jsd = species_data[name]['pairwise_jsd']
#     JSD_value_range.extend(jsd)

# import pandas as pd
# jsd_series = pd.Series(JSD_value_range)
# description_jsd = jsd_series.describe()
# print(description_jsd)

# %% [markdown]
# Edge branch length range

# %%
# # Directory and pattern to find JSON files
# dir = '../../results/output_data/model_fitting_result_GN'
# pattern = os.path.join(dir, '*.json')

# # Use glob.glob to find all files matching the pattern
# lf_json_files = glob.glob(pattern)

# branch_length_range = []
# for path in lf_json_files:
#     file_name = os.path.basename(path).rsplit('.', 1)[0]
#     pdf_path = os.path.join(pdf_output_dir, f"{file_name}_GN.pdf")
#     lf = load_json_app(path)
#     edge_names = lf.tree.get_node_names(includeself = False, tipsonly=True)
#     branch_length_dict = lf.get_lengths_as_ens()
#     edge_branch_length_ens = [branch_length_dict[n] for n in edge_names]
#     branch_length_range.extend(edge_branch_length_ens)
